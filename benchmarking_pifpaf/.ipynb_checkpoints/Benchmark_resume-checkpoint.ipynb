# %%
import os

import pysparkling
import argparse
import datetime
import json
import logging
import os
import subprocess
import numpy as np

# %%
LOG = logging.getLogger(__name__)

# %% [markdown]
# # Benchmarking Resume

# %% [markdown]
# This function is only there to have a resume of all the benchmarking of the different versions of pipaf.

# %% [markdown]
# The benchmarking are done on the validation set of the

# %%
dir_stats = '../openpifpaf/outputs'

# %%
parameters = ["Average Precision  (AP) [%] [ IoU=0.50:0.95 | area=   all | maxDets= 20 ]","Average Precision  (AP) [%] [ IoU=0.50      | area=   all | maxDets= 20 ]",
             "Average Precision  (AP) [%] [ IoU=0.75      | area=   all | maxDets= 20 ]", "Average Precision  (AP) [%] [ IoU=0.50:0.95 | area=medium | maxDets= 20 ]",
             "Average Precision  (AP) [%] [ IoU=0.50:0.95 | area= large | maxDets= 20 ]", "Average Recall     (AR) [%] [ IoU=0.50:0.95 | area=   all | maxDets= 20 ]",
              "Average Recall     (AR) [%] [ IoU=0.50      | area=   all | maxDets= 20 ]", "Average Recall     (AR) [%] [ IoU=0.75      | area=   all | maxDets= 20 ]",
             "Average Recall     (AR) [%] [ IoU=0.50:0.95 | area=medium | maxDets= 20 ]", "Average Recall     (AR) [%] [ IoU=0.50:0.95 | area= large | maxDets= 20 ]", 
             "Decoder time tdec", "Total time t"]

# %%
best_of = {}
for parameter in parameters:
    best_of[parameter] = [0, "0"]
best_of[parameters[10]] = [np.inf, "0"]
best_of[parameters[11]] = [np.inf, "0"]

# %%
for filename in os.listdir(dir_stats):

    
    if filename.endswith('stats.json'):
        
        with open(os.path.join(dir_stats,filename)) as myfile:
            data = json.load(myfile)


            print(str("_"*100)+"\n")

            print(filename+"\n")
            infos = filename.split('-')
            long_edge = None if len(filename.split('_'))==1 else filename.split('_')[2]
            square_edge = infos[3][4:] if not('skeleton' in filename) else infos[4][4:]
            if   1: #"None" in long_edge:#int(square_edge)!= 250 and infos[0]!="resnet101" :
                print(f"Backbone : {infos[0]}")
                print(f"Long edge: {long_edge}")
                print(f"Date : {infos[5]}")
                print(f"Square edge:{square_edge}" )
                print(f"Average Precision  (AP) [ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = {str(100.0 * data['stats'][0])[:4]} % ")
                print(f"Average Precision  (AP) [ IoU=0.50      | area=   all | maxDets= 20 ] = {str(100.0 * data['stats'][1])[:4]} %")
                print(f"Average Precision  (AP) [ IoU=0.75      | area=   all | maxDets= 20 ] = {str(100.0 * data['stats'][2])[:4]} %")
                print(f"Average Precision  (AP) [ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = {str(100.0 * data['stats'][3])[:4]} %")
                print(f"Average Precision  (AP) [ IoU=0.50:0.95 | area= large | maxDets= 20 ] = {str(100.0 * data['stats'][4])[:4]} %")
                print(f"Average Recall     (AR) [ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = {str(100.0 * data['stats'][5])[:4]} %")
                print(f"Average Recall     (AR) [ IoU=0.50      | area=   all | maxDets= 20 ] = {str(100.0 * data['stats'][6])[:4]} %")
                print(f"Average Recall     (AR) [ IoU=0.75      | area=   all | maxDets= 20 ] = {str(100.0 * data['stats'][7])[:4]} %")
                print(f"Average Recall     (AR) [ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = {str(100.0 * data['stats'][8])[:4]} %")
                print(f"Average Recall     (AR) [ IoU=0.50:0.95 | area= large | maxDets= 20 ] = {str(100.0 * data['stats'][9])[:4]} %\n")

                print(f"n images = {data['n_images']}")
                print(f"Decoder time tdec = {1000.0 * data['decoder_time'] / data['n_images']} ")
                print(f"Total time t = {1000.0 * data['total_time'] / data['n_images']} ")

                for i, parameter in enumerate(parameters):
                    name =  str(infos[0])+" "+str(infos[5])+" "+"_SE = "+str(square_edge)+"_LE = "+str(long_edge) 

                    if i < 10 and (best_of[parameter][0]<100.0 * data['stats'][i]):
                            best_of[parameter] =[100.0 * data['stats'][i] , name]
                    if i == 10 and (best_of[parameter][0] > 1000.0 * data['decoder_time'] / data['n_images']):
                            best_of[parameter] = [1000.0 * data['decoder_time'] / data['n_images'], name]

                    if i == 11 and (best_of[parameter][0] > 1000.0 * data['total_time'] / data['n_images']):
                            best_of[parameter] = [1000.0 * data['total_time'] / data['n_images'], name]
# Out:
# ____________________________________________________________________________________________________
#
# pifpaf-pif-paf-edge800-191219-224401-e3cea4a3.pkl_le_420_.stats.json
#
# ____________________________________________________________________________________________________
#
# pifpaf-pif-paf-edge420-191216-190523-9005f8e9.pkl_le_420_.stats.json
#
# Backbone : pifpaf
# Long edge: 420
# Date : 190523
# Square edge:420
# Average Precision  (AP) [ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 24.5 %
# Average Precision  (AP) [ IoU=0.50      | area=   all | maxDets= 20 ] = 47.7 %
# Average Precision  (AP) [ IoU=0.75      | area=   all | maxDets= 20 ] = 22.8 %
# Average Precision  (AP) [ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 3.12 %
# Average Precision  (AP) [ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 24.7 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 31.6 %
# Average Recall     (AR) [ IoU=0.50      | area=   all | maxDets= 20 ] = 56.7 %
# Average Recall     (AR) [ IoU=0.75      | area=   all | maxDets= 20 ] = 31.0 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 4.30 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 32.0 %
#
# n images = 12761
# Decoder time tdec = 38.391335774402826
# Total time t = 52.69426756186897
# ____________________________________________________________________________________________________
#
# pifpaf-pif-paf-edge420-191216-190523-9005f8e9.pkl_le_800_.stats.json
#
# Backbone : pifpaf
# Long edge: 800
# Date : 190523
# Square edge:420
# Average Precision  (AP) [ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 53.4 %
# Average Precision  (AP) [ IoU=0.50      | area=   all | maxDets= 20 ] = 76.4 %
# Average Precision  (AP) [ IoU=0.75      | area=   all | maxDets= 20 ] = 58.8 %
# Average Precision  (AP) [ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 1.52 %
# Average Precision  (AP) [ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 54.1 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 61.8 %
# Average Recall     (AR) [ IoU=0.50      | area=   all | maxDets= 20 ] = 83.5 %
# Average Recall     (AR) [ IoU=0.75      | area=   all | maxDets= 20 ] = 66.9 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 17.2 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 62.5 %
#
# n images = 12761
# Decoder time tdec = 87.92256109972462
# Total time t = 121.06133973969345
# ____________________________________________________________________________________________________
#
# resnet50-pif-paf-skeleton-edge420-191216-181250-7286c95c.pkl_le_420_.stats.json
#
# Backbone : resnet50
# Long edge: 420
# Date : 191216
# Square edge:420
# Average Precision  (AP) [ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 19.6 %
# Average Precision  (AP) [ IoU=0.50      | area=   all | maxDets= 20 ] = 43.0 %
# Average Precision  (AP) [ IoU=0.75      | area=   all | maxDets= 20 ] = 15.3 %
# Average Precision  (AP) [ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 4.59 %
# Average Precision  (AP) [ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 19.8 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 34.0 %
# Average Recall     (AR) [ IoU=0.50      | area=   all | maxDets= 20 ] = 63.7 %
# Average Recall     (AR) [ IoU=0.75      | area=   all | maxDets= 20 ] = 31.4 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 7.74 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 34.4 %
#
# n images = 12761
# Decoder time tdec = 40.145887273856616
# Total time t = 51.85793191790067
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge420-191228-163858-5131e6a6.pkl_le_420_.stats.json
#
# Backbone : resnet101
# Long edge: 420
# Date : 191228
# Square edge:420
# Average Precision  (AP) [ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 31.8 %
# Average Precision  (AP) [ IoU=0.50      | area=   all | maxDets= 20 ] = 53.2 %
# Average Precision  (AP) [ IoU=0.75      | area=   all | maxDets= 20 ] = 32.8 %
# Average Precision  (AP) [ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 7.22 %
# Average Precision  (AP) [ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 32.2 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 42.4 %
# Average Recall     (AR) [ IoU=0.50      | area=   all | maxDets= 20 ] = 64.9 %
# Average Recall     (AR) [ IoU=0.75      | area=   all | maxDets= 20 ] = 44.7 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 9.35 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 42.8 %
#
# n images = 12761
# Decoder time tdec = 35.5877935169226
# Total time t = 53.70335610306531
# ____________________________________________________________________________________________________
#
# resnet50-pif-paf-skeleton-edge250-191211-130342-4ee37969.pkl_le_420_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge420-191228-163858-5131e6a6.pkl_le_800_.stats.json
#
# Backbone : resnet101
# Long edge: 800
# Date : 191228
# Square edge:420
# Average Precision  (AP) [ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 61.0 %
# Average Precision  (AP) [ IoU=0.50      | area=   all | maxDets= 20 ] = 79.3 %
# Average Precision  (AP) [ IoU=0.75      | area=   all | maxDets= 20 ] = 67.8 %
# Average Precision  (AP) [ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 1.44 %
# Average Precision  (AP) [ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 61.8 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 70.2 %
# Average Recall     (AR) [ IoU=0.50      | area=   all | maxDets= 20 ] = 86.3 %
# Average Recall     (AR) [ IoU=0.75      | area=   all | maxDets= 20 ] = 76.3 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 22.7 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 71.0 %
#
# n images = 12761
# Decoder time tdec = 92.34156324914598
# Total time t = 137.7696495296794
# ____________________________________________________________________________________________________
#
# resnet50-pif-paf-skeleton-edge250-191211-130342-4ee37969.pkl_le_800_.stats.json
#
# ____________________________________________________________________________________________________
#
# pifpaf-pif-paf-edge420-191216-190523-9005f8e9.pkl_le_1200_.stats.json
#
# Backbone : pifpaf
# Long edge: 1200
# Date : 190523
# Square edge:420
# Average Precision  (AP) [ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 62.9 %
# Average Precision  (AP) [ IoU=0.50      | area=   all | maxDets= 20 ] = 84.5 %
# Average Precision  (AP) [ IoU=0.75      | area=   all | maxDets= 20 ] = 70.1 %
# Average Precision  (AP) [ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 0.91 %
# Average Precision  (AP) [ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 63.8 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 71.6 %
# Average Recall     (AR) [ IoU=0.50      | area=   all | maxDets= 20 ] = 91.4 %
# Average Recall     (AR) [ IoU=0.75      | area=   all | maxDets= 20 ] = 77.6 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 24.1 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 72.4 %
#
# n images = 12761
# Decoder time tdec = 189.41878711802704
# Total time t = 256.20824931398585
# ____________________________________________________________________________________________________
#
# pifpaf-pif-paf-edge800-191219-224401-e3cea4a3.pkl_le_800_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet50-pif-paf-skeleton-edge420-191216-181250-7286c95c.pkl_le_800_.stats.json
#
# Backbone : resnet50
# Long edge: 800
# Date : 191216
# Square edge:420
# Average Precision  (AP) [ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 49.5 %
# Average Precision  (AP) [ IoU=0.50      | area=   all | maxDets= 20 ] = 73.7 %
# Average Precision  (AP) [ IoU=0.75      | area=   all | maxDets= 20 ] = 53.8 %
# Average Precision  (AP) [ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 1.01 %
# Average Precision  (AP) [ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 50.2 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 64.4 %
# Average Recall     (AR) [ IoU=0.50      | area=   all | maxDets= 20 ] = 87.5 %
# Average Recall     (AR) [ IoU=0.75      | area=   all | maxDets= 20 ] = 70.0 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 22.7 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 65.1 %
#
# n images = 12761
# Decoder time tdec = 129.61103370910263
# Total time t = 159.3433803043884
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge800-200103-003623-d517bd0c.pkl_le_800_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge800-200103-003623-d517bd0c.pkl_le_420_.stats.json
#
# ____________________________________________________________________________________________________
#
# pifpaf-pif-paf-edge800-191219-224401-e3cea4a3.pkl_le_1200_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge420-191228-163858-5131e6a6.pkl_le_1200_.stats.json
#
# Backbone : resnet101
# Long edge: 1200
# Date : 191228
# Square edge:420
# Average Precision  (AP) [ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 68.8 %
# Average Precision  (AP) [ IoU=0.50      | area=   all | maxDets= 20 ] = 86.4 %
# Average Precision  (AP) [ IoU=0.75      | area=   all | maxDets= 20 ] = 76.4 %
# Average Precision  (AP) [ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 1.21 %
# Average Precision  (AP) [ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 69.9 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 78.2 %
# Average Recall     (AR) [ IoU=0.50      | area=   all | maxDets= 20 ] = 93.2 %
# Average Recall     (AR) [ IoU=0.75      | area=   all | maxDets= 20 ] = 84.1 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 30.4 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 79.0 %
#
# n images = 12761
# Decoder time tdec = 158.58654978566267
# Total time t = 254.70057166058967
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge800-200103-003623-d517bd0c.pkl_le_1200_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet50-pif-paf-skeleton-edge250-191211-130342-4ee37969.pkl_le_1200_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet50-pif-paf-skeleton-edge420-191216-181250-7286c95c.pkl_le_1200_.stats.json
#
# Backbone : resnet50
# Long edge: 1200
# Date : 191216
# Square edge:420
# Average Precision  (AP) [ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 57.8 %
# Average Precision  (AP) [ IoU=0.50      | area=   all | maxDets= 20 ] = 80.0 %
# Average Precision  (AP) [ IoU=0.75      | area=   all | maxDets= 20 ] = 64.5 %
# Average Precision  (AP) [ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 0.53 %
# Average Precision  (AP) [ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 58.8 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 71.6 %
# Average Recall     (AR) [ IoU=0.50      | area=   all | maxDets= 20 ] = 92.4 %
# Average Recall     (AR) [ IoU=0.75      | area=   all | maxDets= 20 ] = 78.0 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 29.3 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 72.4 %
#
# n images = 12761
# Decoder time tdec = 164.10584330144823
# Total time t = 220.43547717374597
# ____________________________________________________________________________________________________
#
# pifpaf-pif-paf-edge420-191216-190523-9005f8e9.pkl_le_250_.stats.json
#
# Backbone : pifpaf
# Long edge: 250
# Date : 190523
# Square edge:420
# Average Precision  (AP) [ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 3.68 %
# Average Precision  (AP) [ IoU=0.50      | area=   all | maxDets= 20 ] = 11.0 %
# Average Precision  (AP) [ IoU=0.75      | area=   all | maxDets= 20 ] = 1.66 %
# Average Precision  (AP) [ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 0.0 %
# Average Precision  (AP) [ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 3.72 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 6.44 %
# Average Recall     (AR) [ IoU=0.50      | area=   all | maxDets= 20 ] = 16.3 %
# Average Recall     (AR) [ IoU=0.75      | area=   all | maxDets= 20 ] = 4.02 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 0.0 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 6.41 %
#
# n images = 12761
# Decoder time tdec = 19.051837080667926
# Total time t = 30.95487869698541
# ____________________________________________________________________________________________________
#
# pifpaf-pif-paf-edge800-191219-224401-e3cea4a3.pkl_le_250_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge420-191228-163858-5131e6a6.pkl_le_250_.stats.json
#
# Backbone : resnet101
# Long edge: 250
# Date : 191228
# Square edge:420
# Average Precision  (AP) [ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 6.13 %
# Average Precision  (AP) [ IoU=0.50      | area=   all | maxDets= 20 ] = 14.7 %
# Average Precision  (AP) [ IoU=0.75      | area=   all | maxDets= 20 ] = 4.40 %
# Average Precision  (AP) [ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 1.78 %
# Average Precision  (AP) [ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 6.20 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 10.3 %
# Average Recall     (AR) [ IoU=0.50      | area=   all | maxDets= 20 ] = 21.1 %
# Average Recall     (AR) [ IoU=0.75      | area=   all | maxDets= 20 ] = 8.99 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 1.29 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 10.3 %
#
# n images = 12761
# Decoder time tdec = 17.547466682036482
# Total time t = 33.65575001443612
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge800-200103-003623-d517bd0c.pkl_le_250_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet50-pif-paf-skeleton-edge250-191211-130342-4ee37969.pkl_le_250_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet50-pif-paf-skeleton-edge420-191216-181250-7286c95c.pkl_le_250_.stats.json
#
# Backbone : resnet50
# Long edge: 250
# Date : 191216
# Square edge:420
# Average Precision  (AP) [ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 3.02 %
# Average Precision  (AP) [ IoU=0.50      | area=   all | maxDets= 20 ] = 9.12 %
# Average Precision  (AP) [ IoU=0.75      | area=   all | maxDets= 20 ] = 1.47 %
# Average Precision  (AP) [ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 0.69 %
# Average Precision  (AP) [ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 3.04 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 6.80 %
# Average Recall     (AR) [ IoU=0.50      | area=   all | maxDets= 20 ] = 18.2 %
# Average Recall     (AR) [ IoU=0.75      | area=   all | maxDets= 20 ] = 3.86 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 0.43 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 6.76 %
#
# n images = 12761
# Decoder time tdec = 19.139898817873274
# Total time t = 29.946017345658348
# ____________________________________________________________________________________________________
#
# pifpaf-pif-paf-edge420-191216-190523-9005f8e9.pkl_le_None_.stats.json
#
# Backbone : pifpaf
# Long edge: None
# Date : 190523
# Square edge:420
# Average Precision  (AP) [ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 45.7 %
# Average Precision  (AP) [ IoU=0.50      | area=   all | maxDets= 20 ] = 70.1 %
# Average Precision  (AP) [ IoU=0.75      | area=   all | maxDets= 20 ] = 49.2 %
# Average Precision  (AP) [ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 4.49 %
# Average Precision  (AP) [ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 46.3 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 54.0 %
# Average Recall     (AR) [ IoU=0.50      | area=   all | maxDets= 20 ] = 77.8 %
# Average Recall     (AR) [ IoU=0.75      | area=   all | maxDets= 20 ] = 57.8 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 16.4 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 54.6 %
#
# n images = 12761
# Decoder time tdec = 62.25457881302828
# Total time t = 86.01744206158516
# ____________________________________________________________________________________________________
#
# pifpaf-pif-paf-edge800-191219-224401-e3cea4a3.pkl_le_None_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge420-191228-163858-5131e6a6.pkl_le_None_.stats.json
#
# Backbone : resnet101
# Long edge: None
# Date : 191228
# Square edge:420
# Average Precision  (AP) [ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 53.7 %
# Average Precision  (AP) [ IoU=0.50      | area=   all | maxDets= 20 ] = 74.0 %
# Average Precision  (AP) [ IoU=0.75      | area=   all | maxDets= 20 ] = 59.7 %
# Average Precision  (AP) [ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 2.00 %
# Average Precision  (AP) [ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 54.4 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 63.5 %
# Average Recall     (AR) [ IoU=0.50      | area=   all | maxDets= 20 ] = 81.7 %
# Average Recall     (AR) [ IoU=0.75      | area=   all | maxDets= 20 ] = 69.1 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 18.2 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 64.2 %
#
# n images = 12761
# Decoder time tdec = 62.74307710293384
# Total time t = 96.77943850038156
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge800-200103-003623-d517bd0c.pkl_le_None_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet50-pif-paf-skeleton-edge250-191211-130342-4ee37969.pkl_le_None_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet50-pif-paf-skeleton-edge420-191216-181250-7286c95c.pkl_le_None_.stats.json
#
# Backbone : resnet50
# Long edge: None
# Date : 191216
# Square edge:420
# Average Precision  (AP) [ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 41.3 %
# Average Precision  (AP) [ IoU=0.50      | area=   all | maxDets= 20 ] = 67.5 %
# Average Precision  (AP) [ IoU=0.75      | area=   all | maxDets= 20 ] = 43.0 %
# Average Precision  (AP) [ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 1.82 %
# Average Precision  (AP) [ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 41.8 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 57.0 %
# Average Recall     (AR) [ IoU=0.50      | area=   all | maxDets= 20 ] = 83.5 %
# Average Recall     (AR) [ IoU=0.75      | area=   all | maxDets= 20 ] = 61.0 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 15.0 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 57.7 %
#
# n images = 12761
# Decoder time tdec = 67.13087121095155
# Total time t = 86.6665118783724
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge250-200106-183157-f2ce94bb.pkl_le_1200_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge250-200106-183157-f2ce94bb.pkl_le_420_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge250-200106-183157-f2ce94bb.pkl_le_250_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge250-200106-183157-f2ce94bb.pkl_le_None_.stats.json
#
# ____________________________________________________________________________________________________
#
# pifpaf-pif-paf-edge420-191216-190523-9005f8e9.pkl_le_1300_.stats.json
#
# Backbone : pifpaf
# Long edge: 1300
# Date : 190523
# Square edge:420
# Average Precision  (AP) [ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 63.7 %
# Average Precision  (AP) [ IoU=0.50      | area=   all | maxDets= 20 ] = 85.2 %
# Average Precision  (AP) [ IoU=0.75      | area=   all | maxDets= 20 ] = 71.1 %
# Average Precision  (AP) [ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 0.89 %
# Average Precision  (AP) [ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 64.7 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 72.6 %
# Average Recall     (AR) [ IoU=0.50      | area=   all | maxDets= 20 ] = 92.3 %
# Average Recall     (AR) [ IoU=0.75      | area=   all | maxDets= 20 ] = 78.7 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 22.4 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 73.4 %
#
# n images = 12761
# Decoder time tdec = 167.27809273719862
# Total time t = 240.35810099603913
# ____________________________________________________________________________________________________
#
# pifpaf-pif-paf-edge800-191219-224401-e3cea4a3.pkl_le_1300_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge250-200106-183157-f2ce94bb.pkl_le_1300_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge420-191228-163858-5131e6a6.pkl_le_1300_.stats.json
#
# Backbone : resnet101
# Long edge: 1300
# Date : 191228
# Square edge:420
# Average Precision  (AP) [ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 69.3 %
# Average Precision  (AP) [ IoU=0.50      | area=   all | maxDets= 20 ] = 86.7 %
# Average Precision  (AP) [ IoU=0.75      | area=   all | maxDets= 20 ] = 77.0 %
# Average Precision  (AP) [ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 1.24 %
# Average Precision  (AP) [ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 70.4 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 78.8 %
# Average Recall     (AR) [ IoU=0.50      | area=   all | maxDets= 20 ] = 93.8 %
# Average Recall     (AR) [ IoU=0.75      | area=   all | maxDets= 20 ] = 84.6 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 35.0 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 79.7 %
#
# n images = 12761
# Decoder time tdec = 185.11722545134674
# Total time t = 299.90383323368707
# ____________________________________________________________________________________________________
#
# pifpaf-pif-paf-edge420-191216-190523-9005f8e9.pkl_le_1500_.stats.json
#
# Backbone : pifpaf
# Long edge: 1500
# Date : 190523
# Square edge:420
# Average Precision  (AP) [ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 64.4 %
# Average Precision  (AP) [ IoU=0.50      | area=   all | maxDets= 20 ] = 85.5 %
# Average Precision  (AP) [ IoU=0.75      | area=   all | maxDets= 20 ] = 71.7 %
# Average Precision  (AP) [ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 0.80 %
# Average Precision  (AP) [ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 65.4 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 73.8 %
# Average Recall     (AR) [ IoU=0.50      | area=   all | maxDets= 20 ] = 93.1 %
# Average Recall     (AR) [ IoU=0.75      | area=   all | maxDets= 20 ] = 79.9 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 27.4 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 74.6 %
#
# n images = 12761
# Decoder time tdec = 205.12277651109645
# Total time t = 327.1180587206858
# ____________________________________________________________________________________________________
#
# pifpaf-pif-paf-edge800-191219-224401-e3cea4a3.pkl_le_1500_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge250-200106-183157-f2ce94bb.pkl_le_1500_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge420-191228-163858-5131e6a6.pkl_le_1500_.stats.json
#
# Backbone : resnet101
# Long edge: 1500
# Date : 191228
# Square edge:420
# Average Precision  (AP) [ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 69.9 %
# Average Precision  (AP) [ IoU=0.50      | area=   all | maxDets= 20 ] = 87.2 %
# Average Precision  (AP) [ IoU=0.75      | area=   all | maxDets= 20 ] = 77.6 %
# Average Precision  (AP) [ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 0.91 %
# Average Precision  (AP) [ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 71.1 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 79.8 %
# Average Recall     (AR) [ IoU=0.50      | area=   all | maxDets= 20 ] = 94.6 %
# Average Recall     (AR) [ IoU=0.75      | area=   all | maxDets= 20 ] = 85.6 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 37.6 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 80.7 %
#
# n images = 12761
# Decoder time tdec = 206.64421092948294
# Total time t = 380.10146972686744
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge800-200103-003623-d517bd0c.pkl_le_1500_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet50-pif-paf-skeleton-edge250-191211-130342-4ee37969.pkl_le_1500_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet50-pif-paf-skeleton-edge420-191216-181250-7286c95c.pkl_le_1500_.stats.json
#
# Backbone : resnet50
# Long edge: 1500
# Date : 191216
# Square edge:420
# Average Precision  (AP) [ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 58.4 %
# Average Precision  (AP) [ IoU=0.50      | area=   all | maxDets= 20 ] = 80.1 %
# Average Precision  (AP) [ IoU=0.75      | area=   all | maxDets= 20 ] = 65.2 %
# Average Precision  (AP) [ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 0.50 %
# Average Precision  (AP) [ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 59.7 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 72.1 %
# Average Recall     (AR) [ IoU=0.50      | area=   all | maxDets= 20 ] = 92.7 %
# Average Recall     (AR) [ IoU=0.75      | area=   all | maxDets= 20 ] = 78.7 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 36.6 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 72.9 %
#
# n images = 12761
# Decoder time tdec = 228.9811058224124
# Total time t = 315.0247144396426
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge450-200108-234443-57103ef9.pkl_le_1500_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge450-200108-234443-57103ef9.pkl_le_1300_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge800-200103-003623-d517bd0c.pkl_le_1300_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet50-pif-paf-skeleton-edge250-191211-130342-4ee37969.pkl_le_1300_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet50-pif-paf-skeleton-edge420-191216-181250-7286c95c.pkl_le_1300_.stats.json
#
# Backbone : resnet50
# Long edge: 1300
# Date : 191216
# Square edge:420
# Average Precision  (AP) [ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 58.2 %
# Average Precision  (AP) [ IoU=0.50      | area=   all | maxDets= 20 ] = 80.2 %
# Average Precision  (AP) [ IoU=0.75      | area=   all | maxDets= 20 ] = 64.9 %
# Average Precision  (AP) [ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 0.60 %
# Average Precision  (AP) [ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 59.4 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 72.0 %
# Average Recall     (AR) [ IoU=0.50      | area=   all | maxDets= 20 ] = 92.5 %
# Average Recall     (AR) [ IoU=0.75      | area=   all | maxDets= 20 ] = 78.5 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 33.3 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 72.8 %
#
# n images = 12761
# Decoder time tdec = 192.48128842920633
# Total time t = 376.0770440391216
# ____________________________________________________________________________________________________
#
# pifpaf-pif-paf-edge420-191216-190523-9005f8e9.pkl_le_1100_.stats.json
#
# Backbone : pifpaf
# Long edge: 1100
# Date : 190523
# Square edge:420
# Average Precision  (AP) [ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 61.6 %
# Average Precision  (AP) [ IoU=0.50      | area=   all | maxDets= 20 ] = 83.3 %
# Average Precision  (AP) [ IoU=0.75      | area=   all | maxDets= 20 ] = 68.8 %
# Average Precision  (AP) [ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 1.13 %
# Average Precision  (AP) [ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 62.4 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 70.2 %
# Average Recall     (AR) [ IoU=0.50      | area=   all | maxDets= 20 ] = 90.3 %
# Average Recall     (AR) [ IoU=0.75      | area=   all | maxDets= 20 ] = 76.4 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 21.8 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 71.0 %
#
# n images = 12761
# Decoder time tdec = 151.16566258566783
# Total time t = 307.43400722300686
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge250-200109-220207-f548e7f3.pkl_le_1200_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge250-200109-220207-f548e7f3.pkl_le_1500_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge450-200108-234443-57103ef9.pkl_le_1200_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge250-200106-183157-f2ce94bb.pkl_le_800_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge250-200109-220207-f548e7f3.pkl_le_1300_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge250-200109-220207-f548e7f3.pkl_le_800_.stats.json
#
# ____________________________________________________________________________________________________
#
# pifpaf-pif-paf-edge800-191219-224401-e3cea4a3.pkl_le_1100_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge450-200108-234443-57103ef9.pkl_le_800_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge250-200109-220207-f548e7f3.pkl_le_420_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge450-200108-234443-57103ef9.pkl_le_420_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge250-200109-220207-f548e7f3.pkl_le_250_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge450-200108-234443-57103ef9.pkl_le_250_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge250-200106-183157-f2ce94bb.pkl_le_1100_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge250-200109-220207-f548e7f3.pkl_le_None_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge450-200108-234443-57103ef9.pkl_le_None_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge250-200109-220207-f548e7f3.pkl_le_1100_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge420-191228-163858-5131e6a6.pkl_le_1100_.stats.json
#
# Backbone : resnet101
# Long edge: 1100
# Date : 191228
# Square edge:420
# Average Precision  (AP) [ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 67.9 %
# Average Precision  (AP) [ IoU=0.50      | area=   all | maxDets= 20 ] = 85.6 %
# Average Precision  (AP) [ IoU=0.75      | area=   all | maxDets= 20 ] = 75.2 %
# Average Precision  (AP) [ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 1.39 %
# Average Precision  (AP) [ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 68.9 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 77.1 %
# Average Recall     (AR) [ IoU=0.50      | area=   all | maxDets= 20 ] = 92.2 %
# Average Recall     (AR) [ IoU=0.75      | area=   all | maxDets= 20 ] = 82.9 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 29.4 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 77.9 %
#
# n images = 12761
# Decoder time tdec = 148.43980524177064
# Total time t = 379.8024501932068
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge450-200108-234443-57103ef9.pkl_le_1100_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge800-200103-003623-d517bd0c.pkl_le_1100_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet50-pif-paf-skeleton-edge250-191211-130342-4ee37969.pkl_le_1100_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet50-pif-paf-skeleton-edge420-191216-181250-7286c95c.pkl_le_1100_.stats.json
#
# Backbone : resnet50
# Long edge: 1100
# Date : 191216
# Square edge:420
# Average Precision  (AP) [ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 56.6 %
# Average Precision  (AP) [ IoU=0.50      | area=   all | maxDets= 20 ] = 79.1 %
# Average Precision  (AP) [ IoU=0.75      | area=   all | maxDets= 20 ] = 62.9 %
# Average Precision  (AP) [ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 0.69 %
# Average Precision  (AP) [ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 57.6 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 70.7 %
# Average Recall     (AR) [ IoU=0.50      | area=   all | maxDets= 20 ] = 91.7 %
# Average Recall     (AR) [ IoU=0.75      | area=   all | maxDets= 20 ] = 77.1 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 32.0 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 71.4 %
#
# n images = 12761
# Decoder time tdec = 146.74055409794266
# Total time t = 196.83969595357362
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge240-200112-231927-412c34a1.pkl_le_1500_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge410-200112-231732-681fd8b2.pkl_le_1500_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge240-200112-231927-412c34a1.pkl_le_1300_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge410-200112-231732-681fd8b2.pkl_le_1300_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge240-200112-231927-412c34a1.pkl_le_1100_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge410-200112-231732-681fd8b2.pkl_le_1100_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge240-200112-231927-412c34a1.pkl_le_1200_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge410-200112-231732-681fd8b2.pkl_le_1200_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge240-200112-231927-412c34a1.pkl_le_800_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge410-200112-231732-681fd8b2.pkl_le_800_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge240-200112-231927-412c34a1.pkl_le_420_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge410-200112-231732-681fd8b2.pkl_le_420_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge240-200112-231927-412c34a1.pkl_le_250_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge410-200112-231732-681fd8b2.pkl_le_250_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge240-200112-231927-412c34a1.pkl_le_None_.stats.json
#
# ____________________________________________________________________________________________________
#
# pifpaf-pif-paf-edge420-191216-190523-9005f8e9.pkl_le_1800_.stats.json
#
# Backbone : pifpaf
# Long edge: 1800
# Date : 190523
# Square edge:420
# Average Precision  (AP) [ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 63.6 %
# Average Precision  (AP) [ IoU=0.50      | area=   all | maxDets= 20 ] = 84.8 %
# Average Precision  (AP) [ IoU=0.75      | area=   all | maxDets= 20 ] = 71.2 %
# Average Precision  (AP) [ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 0.97 %
# Average Precision  (AP) [ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 64.9 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 73.9 %
# Average Recall     (AR) [ IoU=0.50      | area=   all | maxDets= 20 ] = 93.3 %
# Average Recall     (AR) [ IoU=0.75      | area=   all | maxDets= 20 ] = 80.1 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 34.7 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 74.7 %
#
# n images = 12761
# Decoder time tdec = 313.1235837440854
# Total time t = 519.039862545089
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge410-200112-231732-681fd8b2.pkl_le_None_.stats.json
#
# ____________________________________________________________________________________________________
#
# pifpaf-pif-paf-edge800-191219-224401-e3cea4a3.pkl_le_1800_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge240-200112-231927-412c34a1.pkl_le_1800_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge250-200106-183157-f2ce94bb.pkl_le_1800_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge250-200109-220207-f548e7f3.pkl_le_1800_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge410-200112-231732-681fd8b2.pkl_le_1800_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge420-191228-163858-5131e6a6.pkl_le_1800_.stats.json
#
# Backbone : resnet101
# Long edge: 1800
# Date : 191228
# Square edge:420
# Average Precision  (AP) [ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 69.5 %
# Average Precision  (AP) [ IoU=0.50      | area=   all | maxDets= 20 ] = 87.1 %
# Average Precision  (AP) [ IoU=0.75      | area=   all | maxDets= 20 ] = 77.2 %
# Average Precision  (AP) [ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 0.79 %
# Average Precision  (AP) [ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 70.9 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 80.1 %
# Average Recall     (AR) [ IoU=0.50      | area=   all | maxDets= 20 ] = 95.3 %
# Average Recall     (AR) [ IoU=0.75      | area=   all | maxDets= 20 ] = 85.8 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 39.8 %
# Average Recall     (AR) [ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 81.0 %
#
# n images = 12761
# Decoder time tdec = 255.05014242629628
# Total time t = 518.0612785410203
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge450-200108-234443-57103ef9.pkl_le_1800_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet101-pif-paf-skeleton-edge800-200103-003623-d517bd0c.pkl_le_1800_.stats.json
#
# ____________________________________________________________________________________________________
#
# resnet50-pif-paf-skeleton-edge250-191211-130342-4ee37969.pkl_le_1800_.stats.json

# %%
for key in best_of :
    print(key+" = " + str(best_of[key][0])[:4]+" from : "+str(best_of[key][1]))
# Out:
# Average Precision  (AP) [%] [ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 69.9 from : resnet101 191228 _SE = 420_LE = 1500
# Average Precision  (AP) [%] [ IoU=0.50      | area=   all | maxDets= 20 ] = 87.2 from : resnet101 191228 _SE = 420_LE = 1500
# Average Precision  (AP) [%] [ IoU=0.75      | area=   all | maxDets= 20 ] = 77.6 from : resnet101 191228 _SE = 420_LE = 1500
# Average Precision  (AP) [%] [ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 7.22 from : resnet101 191228 _SE = 420_LE = 420
# Average Precision  (AP) [%] [ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 71.1 from : resnet101 191228 _SE = 420_LE = 1500
# Average Recall     (AR) [%] [ IoU=0.50:0.95 | area=   all | maxDets= 20 ] = 80.1 from : resnet101 191228 _SE = 420_LE = 1800
# Average Recall     (AR) [%] [ IoU=0.50      | area=   all | maxDets= 20 ] = 95.3 from : resnet101 191228 _SE = 420_LE = 1800
# Average Recall     (AR) [%] [ IoU=0.75      | area=   all | maxDets= 20 ] = 85.8 from : resnet101 191228 _SE = 420_LE = 1800
# Average Recall     (AR) [%] [ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = 39.8 from : resnet101 191228 _SE = 420_LE = 1800
# Average Recall     (AR) [%] [ IoU=0.50:0.95 | area= large | maxDets= 20 ] = 81.0 from : resnet101 191228 _SE = 420_LE = 1800
# Decoder time tdec = 17.5 from : resnet101 191228 _SE = 420_LE = 250
# Total time t = 29.9 from : resnet50 191216 _SE = 420_LE = 250
